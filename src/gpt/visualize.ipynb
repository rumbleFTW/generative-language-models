# %%
import json
import matplotlib.pyplot as plt

# %%
with open('../../index_tables/gpt.json', 'r') as f:
    vals = json.loads(f.read())

print(vals)
# Out:
# {'first': [-4.706212043762207, 5.283426284790039], 'vikarna': [-4.785809516906738, 5.522083759307861], 'roar': [-5.406131744384766, 4.603099346160889], 'slips': [-5.015084266662598, 5.047393321990967], 'ease': [-5.536269187927246, 5.1824235916137695], 'goodly': [-4.58280086517334, 5.632988929748535], 'sons': [-5.50215482711792, 5.027487754821777], 'fn': [-5.504872798919678, 4.790854454040527], 'therein': [-4.958657264709473, 4.658134937286377], 'weak': [-4.855006217956543, 5.608511924743652], 'this': [-5.3371710777282715, 5.317104339599609], 'mixed': [-5.105327606201172, 4.920638084411621], 'sinful': [-5.45710563659668, 4.424210548400879], 'forth': [-5.177595615386963, 4.919722557067871], 'gift': [-5.568179130554199, 5.167654991149902], 'open': [-5.043044090270996, 5.104193687438965], 'could': [-5.241817951202393, 5.117105960845947], 'host': [-4.833548069000244, 5.626843452453613], 'milk': [-5.3254289627075195, 4.529359817504883], 'grandsires': [-5.399617671966553, 5.369503498077393], 'divine': [-5.154074668884277, 5.469876766204834], 'less': [-5.444945812225342, 4.826834201812744], 'deaths': [-5.466891765594482, 5.319209575653076], 'pity': [-5.25549840927124, 5.014201641082764], 'blowing': [-5.3550896644592285, 5.390083312988281], 'fair': [-5.566938877105713, 4.739170551300049], 'kith': [-5.11334753036499, 4.7782087326049805], 'light': [-4.741329669952393, 5.288878917694092], 's': [-5.6582536697387695, 5.160816192626953], 'to': [-4.997089862823486, 5.584756374359131], 'blew': [-5.379130840301514, 5.178762435913086], 'slay': [-5.163555145263672, 5.576288223266602], 'seems': [-5.275099754333496, 5.0878071784973145], 'led': [-5.431682586669922, 4.709046363830566], 'precious': [-5.421454429626465, 5.22469425201416], 'aho': [-5.588374137878418, 4.848184108734131], 'was': [-4.82265043258667, 5.1485772132873535], 'named': [-5.1793212890625, 5.301613807678223], 'kin': [-5.210086345672607, 5.079020977020264], 'fierce': [-5.109606742858887, 5.307088375091553], 'from': [-4.905162334442139, 5.340780735015869], 'blameless': [-4.721464157104492, 5.236241817474365], 'benders': [-4.981062889099121, 5.107373237609863], 'terrible': [-5.4268717765808105, 5.04981803894043], 'reining': [-5.207302093505859, 4.753333568572998], 'drive': [-4.848503589630127, 5.549757480621338], 'kingdom': [-5.52032470703125, 5.156106948852539], 'doom': [-5.47488260269165, 4.5519866943359375], 'line': [-5.281441688537598, 5.101633548736572], 'strong': [-5.255305767059326, 5.572756290435791], 'ranged': [-5.227284908294678, 4.904867649078369], 'swim': [-5.066187858581543, 5.293294429779053], 'the': [-5.375964164733887, 5.410916805267334], 'ranked': [-5.312753200531006, 4.646419048309326], 'gandiv': [-5.385584354400635, 4.683242321014404], 'be': [-5.2810163497924805, 5.534065246582031], 'weakest': [-5.4138007164001465, 5.1290717124938965], 'unsheathing': [-5.449965953826904, 4.6704816818237305], 'rule': [-5.136417865753174, 4.996528625488281], 'mouth': [-5.404736518859863, 5.299943447113037], 'wrath': [-5.044993877410889, 4.969323635101318], 'shudder': [-4.911373615264893, 5.089494705200195], 'seek': [-5.640938758850098, 4.63351583480835], 'mad': [-5.00547981262207, 5.418464183807373], 'crime': [-5.319818496704102, 4.906251430511475], 'trumpets': [-4.964454650878906, 4.628542900085449], 'gold': [-5.4307098388671875, 4.8155412673950195], 'sure': [-5.106698036193848, 4.720622539520264], 'hardly': [-5.084514617919922, 4.927090644836426], 'fall': [-4.904642105102539, 4.939789295196533], 'nay': [-5.199222087860107, 4.541756629943848], 'something': [-5.26591157913208, 5.454269886016846], 'our': [-5.478311061859131, 5.143526554107666], 'charioteer': [-5.314726829528809, 5.023229122161865], 'thing': [-5.032107353210449, 4.886841773986816], 'gita': [-5.113897323608398, 5.316156387329102], 'uttamauj': [-4.845137596130371, 5.023915767669678], 'instant': [-5.468789100646973, 5.316213130950928], 'thus': [-5.0030927658081055, 5.041407585144043], 'should': [-5.416762828826904, 4.81616 ...

# %%
vectors = vals.values()
labels = vals.keys()

x = [v[0] for v in vectors]
y = [v[1] for v in vectors]
# z = [v[2] for v in vectors]

# %%
plt.figure(figsize=(20, 20))
plt.scatter(x, y)
for i, label in enumerate(labels):
    plt.annotate(label, (x[i], y[i]))
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('2D Vector Visualization')
plt.show()

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z)
for i, label in enumerate(labels):
    ax.text(x[i], y[i], z[i], label)
ax.set_xlabel('Dimension 1')
ax.set_ylabel('Dimension 2')
ax.set_zlabel('Dimension 3')
ax.set_title('3D Vector Visualization')
plt.show()
